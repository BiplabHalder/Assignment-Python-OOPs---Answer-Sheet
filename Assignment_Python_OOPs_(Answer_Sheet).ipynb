# %% [markdown]
# #Python OOPs Questions
#  1. What is Object-oriented Programming (OOP)?
#   - Object-Oriented Programming (OOP) is a programming paradigm based on the concept of "objects",
# which contain data in the form of fields (attributes) and code in the form of methods.
# It helps in organizing complex programs, promotes code reusability, and improves maintainability.
#
#
#  2. What is a class in OOP?
#   - A class is a blueprint for creating objects. It defines a set of attributes and methods
# that the created objects (instances) will have.
#
#
#  3. What is an object in OOP?
#   - An object is an instance of a class. It represents a specific implementation of the class
# with actual values and can use the class methods and attributes.
#
#  4. What is the difference between abstraction and encapsulation?
#   - Abstraction hides complexity by showing only essential details. Encapsulation binds data and
# methods together and restricts direct access to some of the object’s components.
#
#  5. What are dunder methods in Python?
#   - Dunder (double underscore) methods are special methods in Python that start and end with double underscores,
# like __init__, __str__, __len__, etc. They are used to define object behavior for built-in operations.
#
#  6. Explain the concept of inheritance in OOP.
#   - Inheritance allows a class (child) to acquire properties and methods from another class (parent).
# It promotes code reusability and hierarchical relationships.
#
#  7. What is polymorphism in OOP?
#   - Polymorphism means the same function or method can behave differently on different classes or data types.
# It allows different classes to define methods that are called through the same name.
#
#  8. How is encapsulation achieved in Python?
#   - Encapsulation is achieved using private (single or double underscore) variables and providing
# public methods (getters/setters) to access or modify them.
#
#  9. What is a constructor in Python?
#   - A constructor is a special method (__init__) in a class that is automatically called
# when an object is created. It initializes the object's attributes.
#
#  10. What are class and static methods in Python?
#   -  -  Class methods use @classmethod decorator and take 'cls' as the first argument. They can access or modify class state.
#       -  Static methods use @staticmethod and do not take 'self' or 'cls'. They behave like regular functions within a class.
#
# 11. What is method overloading in Python?
#   - Python does not support traditional method overloading. However, it can be achieved using default arguments or *args/**kwargs.
#
#  12. What is method overriding in OOP?
#   - Method overriding allows a subclass to provide a specific implementation of a method already defined in its superclass.
#
#  13. What is a property decorator in Python?
#   - @property is a built-in decorator used to define getter methods. It allows a method to be accessed like an attribute.
#
#  14. Why is polymorphism important in OOP?
#   - Polymorphism increases flexibility and maintainability of code by allowing objects of different classes
# to be treated through a common interface.
#
#  15. What is an abstract class in Python?
#   - An abstract class is a class that cannot be instantiated directly. It can contain abstract methods
# that must be implemented by its child classes. It is defined using the 'abc' module.
#
#  16. What are the advantages of OOP?
#   -     - Code reusability
#         -  Scalability
#         -  Maintainability
#         -  Better organization and structure
#         -  Real-world modeling
#
#
#  17. What is the difference between a class variable and an instance variable?
# -     - Class variables are shared across all instances of a class.
#       - Instance variables are unique to each object.
#
#  18. What is multiple inheritance in Python?
#   - Multiple inheritance means a class can inherit from more than one parent class.
# Example: class C(A, B)
#
#
#  19. Explain the purpose of '__str__' and '__repr__' methods in Python.
#   -     -__str__ returns a readable string representation of an object.
#        - __repr__ returns an unambiguous string useful for debugging and development.
#
#  20. What is the significance of the 'super()' function in Python?
#   -  super() is used to call methods from the parent class. It is commonly used in method overriding and constructors.
#
#  21. What is the significance of the '__del__' method in Python?
#   - __del__ is a destructor method that is called when an object is about to be destroyed.
# It is used to clean up resources.
#
# 22. What is the difference between @staticmethod and @classmethod in Python?
#   -    - @staticmethod does not access class or instance variables.
#        - @classmethod takes the class as its first argument and can modify class state.
#
#  23. How does polymorphism work in Python with inheritance?
#   - In inheritance, a subclass can override methods of the parent class, and Python can call the appropriate method
# based on the object type at runtime.
#
#  24. What is method chaining in Python OOP?
#   - Method chaining is the practice of calling multiple methods on the same object in a single line.
# Each method returns 'self' to continue the chain.
#
#  25. What is the purpose of the '__call__' method in Python?
#   - __call__ allows an instance of a class to be called as if it were a function. It makes objects callable.

# %% [markdown]
# #Practical Questions
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".
#  -	Create a parent class Animal and a child class Dog that overrides speak()
#                  class Animal:
#                 def speak(self):
#                 print("Animal speaks")
#
#             class Dog(Animal):
#             def speak(self):
#             print("Bark!")
#
# -	Output
#               print("1. Output:")
#              dog = Dog()
#             dog.speak()
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.
# -	 Abstract class Shape with Circle and Rectangle classes
#
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#
#     @abstractmethod
#
#     def area(self):
#
#         pass
#
# class Circle(Shape):
#
#     def __init__(self, radius):
#
#         self.radius = radius
#
#     def area(self):
#
#         return 3.14 * self.radius ** 2
#
# class Rectangle(Shape):
#
#     def __init__(self, width, height):
#
#         self.width = width
#
#         self.height = height
#
#     def area(self):
#
#         return self.width * self.height
#
# -	Output
#
# print("2. Output:")
#
# circle = Circle(5)
#
# rectangle = Rectangle(4, 6)
#
# print("Circle Area:", circle.area())
#
# print("Rectangle Area:", rectangle.area())
# 3.  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.
# -  Multi-level Inheritance Example
#
# class Vehicle:
#
#     def __init__(self, v_type):
#
#         self.type = v_type
#
# class Car(Vehicle):
#
#     def __init__(self, v_type, brand):
#
#         super().__init__(v_type)
#
#         self.brand = brand
#
# class ElectricCar(Car):
#
#     def __init__(self, v_type, brand, battery):
#
#         super().__init__(v_type, brand)
#
#         self.battery = battery
#
# -	 Output
#
# print("3. Output:")
#
# ecar = ElectricCar("Car", "Tesla", "100 kWh")
#
# print("Type:", ecar.type)
#
# print("Brand:", ecar.brand)
#
# print("Battery:", ecar.battery)
# 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.
# - Polymorphism with Bird class
#
# class Bird:
#
#     def fly(self):
#
#         print("Bird flies")
#
# class Sparrow(Bird):
#
#     def fly(self):
#
#         print("Sparrow flies high")
#
# class Penguin(Bird):
#
#     def fly(self):
#
#         print("Penguin can't fly")
#
# -	 Output
#
#     print("4. Output:")
#
#     birds = [Sparrow(), Penguin()]
#
#     for bird in birds:
#
#     bird.fly()
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.
# -   Encapsulation in BankAccount
#
# class BankAccount:
#
#     def __init__(self):
#
#         self.__balance = 0
#
#
#     def deposit(self, amount):
#
#         self.__balance += amount
#
#
#     def withdraw(self, amount):
#
#         if amount <= self.__balance:
#
#             self.__balance -= amount
#
#         else:
#
#             print("Insufficient balance")
#
#     def check_balance(self):
#
#         return self.__balance
#
# -	 Output
#
# print("5. Output:")
#
# account = BankAccount()
#
# account.deposit(1000)
#
# account.withdraw(300)
#
# print("Balance:", account.check_balance())
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().
# -   Runtime Polymorphism with Instrument class
#
# class Instrument:
#
#     def play(self):
#
#         print("Playing an instrument")
#
# class Guitar(Instrument):
#
#     def play(self):
#
#         print("Strumming the guitar")
#
# class Piano(Instrument):
#
#     def play(self):
#
#         print("Playing the piano")
#
# -	 Output
#
# print("6. Output:")
#
# instruments = [Guitar(), Piano()]
#
# for i in instruments:
#
#    i.play()
# 7.  Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.
# -  Class and Static Methods
#
# class MathOperations:
#
#     @classmethod
#
#     def add_numbers(cls, a, b):
#
#         return a + b
#
#     @staticmethod
#
#     def subtract_numbers(a, b):
#
#         return a - b
#
# -	 Output
#
# print("7. Output:")
#
# print("Addition:", MathOperations.add_numbers(10, 5))
#
# print("Subtraction:", MathOperations.subtract_numbers(10, 3))
# 8.  Implement a class Person with a class method to count the total number of persons created.
# - Count Persons using Class Method
#
# class Person:
#
#     count = 0
#
#     def __init__(self):
#
#         Person.count += 1
#
#     @classmethod
#
#     def total_persons(cls):
#
#         return cls.count
#
# -	 Output
#
# print("8. Output:")
#
# p1 = Person()
#
# p2 = Person()
#
# print("Total Persons Created:", Person.total_persons())
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".
# -  Override __str__ in Fraction
#
# class Fraction:
#
#     def __init__(self, numerator, denominator):
#
#         self.numerator = numerator
#
#         self.denominator = denominator
#
#     def __str__(self):
#
#         return f"{self.numerator}/{self.denominator}"
#
# -	 Output
#
# print("9. Output:")
#
# f = Fraction(3, 4)
#
# print(f)
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.
# - Operator Overloading with Vector
#
# class Vector:
#
#     def __init__(self, x, y):
#
#         self.x = x
#
#         self.y = y
#
#     def __add__(self, other):
#
#         return Vector(self.x + other.x, self.y + other.y)
#
#     def __str__(self):
#
#         return f"Vector({self.x}, {self.y})"
#
# -	 Output
#
# print("10. Output:")
#
# v1 = Vector(2, 3)
#
# v2 = Vector(4, 1)
#
# v3 = v1 + v2
#
# print(v3)
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."
# -  Person with greet method
#
# class Person2:
#
#     def __init__(self, name, age):
#
#         self.name = name
#
#         self.age = age
#
#     def greet(self):
#
#         print(f"Hello, my name is {self.name} and I am {self.age} years old.")
#
# -	 Output
# print("11. Output:")
#
# person = Person2("Ravi", 25)
#
# person.greet()
# 12.  Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.
# -  Student average grade
#
# class Student:
#
#     def __init__(self, name, grades):
#
#         self.name = name
#
#         self.grades = grades
#
#     def average_grade(self):
#
#         return sum(self.grades) / len(self.grades)
#
# -	 Output
#
# print("12. Output:")
#
# s = Student("Amit", [80, 90, 85])
#
# print("Average Grade:", s.average_grade())
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.
# -  Rectangle with set_dimensions and area
#
# class Rectangle:
#
#     def set_dimensions(self, width, height):
#
#         self.width = width
#
#         self.height = height
#
#     def area(self):
#
#         return self.width * self.height
#
# -	 Output
#
# print("13. Output:")
#
# rect = Rectangle()
#
# rect.set_dimensions(4, 5)
#
# print("Area:", rect.area())
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.
# -  Inheritance: Employee and Manager with salary
#
# class Employee:
#
#     def calculate_salary(self, hours, rate):
#
#         return hours * rate
#
# class Manager(Employee):
#
#     def calculate_salary(self, hours, rate, bonus):
#
#         base = super().calculate_salary(hours, rate)
#
#         return base + bonus
#
# -	 Output
#
# print("14. Output:")
#
# mgr = Manager()
#
# print("Manager Salary:", mgr.calculate_salary(40, 50, 500))
# 15.  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.
# -  Product total price
#
# class Product:
#
#     def __init__(self, name, price, quantity):
#
#         self.name = name
#
#         self.price = price
#
#         self.quantity = quantity
#
#     def total_price(self):
#
#         return self.price * self.quantity
#
# -	 Output
#
# print("15. Output:")
#
# product = Product("Notebook", 50, 3)
#
# print("Total Price:", product.total_price())
# 16.  Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.
# -  Abstract Animal class with sound()
#
# from abc import ABC, abstractmethod
#
# class Animal2(ABC):
#
#     @abstractmethod
#
#     def sound(self):
#
#         pass
#
# class Cow(Animal2):
#
#     def sound(self):
#
#         print("Moo")
#
# class Sheep(Animal2):
#
#     def sound(self):
#
#         print("Baa")
#
# -	 Output
#
# print("16. Output:")
#
# cow = Cow()
#
# sheep = Sheep()
#
# cow.sound()
#
# sheep.sound()
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.
# -  Book get_book_info
#
# class Book:
#
#     def __init__(self, title, author, year_published):
#
#         self.title = title
#
#         self.author = author
#
#         self.year_published = year_published
#
#     def get_book_info(self):
#
#         return f"{self.title} by {self.author}, published in {self.year_published}"
#
# -	 Output
#
# print("17. Output:")
#
# book = Book("Wings of Fire", "A.P.J. Abdul Kalam", 1999)
#
# print(book.get_book_info())
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.
# - House and Mansion classes
#
# class House:
#
#     def __init__(self, address, price):
#
#         self.address = address
#
#         self.price = price
#
# class Mansion(House):
#
#     def __init__(self, address, price, number_of_rooms):
#
#         super().__init__(address, price)
#
#         self.number_of_rooms = number_of_rooms
#
# -  Output
#
# print("18. Output:")
#
# mansion = Mansion("Beverly Hills", 2000000, 10)
#
# print("Address:", mansion.address)
#
# print("Price:", mansion.price)
#
# print("Rooms:", mansion.number_of_rooms)
